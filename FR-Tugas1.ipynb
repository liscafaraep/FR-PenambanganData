# %%
import pandas as pd

# %%
df = pd.read_csv('daftarnilai.csv')
df
# Out:
#     Matematika  Fisika  Kimia  Biologi
# 0           67      77     71       77
# 1           72      83     70       79
# 2           75      92     80       75
# 3           65      79     77       90
# 4           66      72     67       92
# ..         ...     ...    ...      ...
# 95          73      89     70       87
# 96          85      83     85       93
# 97          71      86     84       84
# 98          77      78     77       78
# 99          81      82     83       84
#
# [100 rows x 4 columns]

# %%
from IPython.display import HTML, display
import tabulate
table=[
        ["method"]+[x for x in df.columns],
        ["describe()"]+['<pre>'+str(df[col].describe())+'</pre>' for col in df.columns],
        ["count()"]+[df[col].count() for col in df.columns],
        ["mean()"]+[df[col].mean() for col in df.columns],
        ["std()"]+["{:.2f}".format(df[col].std()) for col in df.columns],
        ["min()"]+[df[col].min() for col in df.columns],
        ["max()"]+[df[col].max() for col in df.columns],
        ["q1()"]+[df[col].quantile(0.25) for col in df.columns],
        ["q2()"]+[df[col].quantile(0.50) for col in df.columns],
        ["q3()"]+[df[col].quantile(0.75) for col in df.columns],
        ["skew()"]+["{:.2f}".format(df[col].skew()) for col in df.columns],
     ]

display(HTML(tabulate.tabulate(table, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>method    </td><td>Matematika</td><td>Fisika</td><td>Kimia</td><td>Biologi</td></tr>
# <tr><td>describe()</td><td><pre>count    100.00000
# mean      76.36000
# std        7.67591
# min       65.00000
# 25%       70.00000
# 50%       76.50000
# 75%       82.00000
# max       90.00000
# Name: Matematika, dtype: float64</pre>           </td><td><pre>count    100.000000
# mean      80.010000
# std        7.372478
# min       68.000000
# 25%       73.000000
# 50%       80.500000
# 75%       85.250000
# max       92.000000
# Name: Fisika, dtype: float64</pre>       </td><td><pre>count    100.000000
# mean      76.890000
# std        6.910532
# min       66.000000
# 25%       70.000000
# 50%       77.000000
# 75%       83.000000
# max       90.000000
# Name: Kimia, dtype: float64</pre>      </td><td><pre>count    100.000000
# mean      82.630000
# std        6.102914
# min       72.000000
# 25%       77.000000
# 50%       82.000000
# 75%       88.000000
# max       94.000000
# Name: Biologi, dtype: float64</pre>        </td></tr>
# <tr><td>count()   </td><td>100       </td><td>100   </td><td>100  </td><td>100    </td></tr>
# <tr><td>mean()    </td><td>76.36     </td><td>80.01 </td><td>76.89</td><td>82.63  </td></tr>
# <tr><td>std()     </td><td>7.68      </td><td>7.37  </td><td>6.91 </td><td>6.10   </td></tr>
# <tr><td>min()     </td><td>65        </td><td>68    </td><td>66   </td><td>72     </td></tr>
# <tr><td>max()     </td><td>90        </td><td>92    </td><td>90   </td><td>94     </td></tr>
# <tr><td>q1()      </td><td>70.0      </td><td>73.0  </td><td>70.0 </td><td>77.0   </td></tr>
# <tr><td>q2()      </td><td>76.5      </td><td>80.5  </td><td>77.0 </td><td>82.0   </td></tr>
# <tr><td>q3()      </td><td>82.0      </td><td>85.25 </td><td>83.0 </td><td>88.0   </td></tr>
# <tr><td>skew()    </td><td>0.23      </td><td>-0.05 </td><td>0.11 </td><td>0.14   </td></tr>
# </tbody>
# </table>
